# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
#defining folder path
path = r'/Users/daniel/Library/CloudStorage/OneDrive-Persönlich/00 Synology/01 Dokumente/2023 Docs/99 CareerFoundry/04 Python/00 Instacart'

# %%
# importing pickle
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_v2.pkl'))

# %%
#limiting to 1m rows
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                1.0        0.0
# 1                    15.0         196                1.0        1.0
# 2                    21.0         196                1.0        1.0
# 3                    29.0         196                1.0        1.0
# 4                    28.0         196                1.0        1.0
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# ## Grouping Data

# %%
df.groupby('product_name')

# %% [markdown]
# ## Aggregating Data

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4.0              18.825780
# 7.0              17.472355
# 13.0             17.993423
# 14.0             19.246334
# 16.0             19.463012
# 17.0             11.294069
# 19.0             19.305237
# 20.0             17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4.0     18.825780
# 7.0     17.472355
# 13.0    17.993423
# 14.0    19.246334
# 16.0    19.463012
# 17.0    11.294069
# 19.0    19.305237
# 20.0    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean  min   max
# department_id
# 4.0              18.825780  1.0  99.0
# 7.0              17.472355  1.0  99.0
# 13.0             17.993423  1.0  99.0
# 14.0             19.246334  1.0  99.0
# 16.0             19.463012  1.0  99.0
# 17.0             11.294069  1.0  98.0
# 19.0             19.305237  1.0  99.0
# 20.0             17.599636  1.0  99.0

# %% [markdown]
# ### Creating a loyalty flag

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                1.0        0.0
# 1                    15.0         196                1.0        1.0
# 2                    21.0         196                1.0        1.0
# 3                    29.0         196                1.0        1.0
# 4                    28.0         196                1.0        1.0
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
ords_prods_merge.head(100)
# Out:
#      order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329.0      1.0           1.0                 2.0                8.0
# 1   2398795.0      1.0           2.0                 3.0                7.0
# 2    473747.0      1.0           3.0                 3.0               12.0
# 3   2254736.0      1.0           4.0                 4.0                7.0
# 4    431534.0      1.0           5.0                 4.0               15.0
# ..        ...      ...           ...                 ...                ...
# 95  3226575.0    360.0           1.0                 5.0               12.0
# 96  1469869.0    377.0           3.0                 5.0               17.0
# 97  1927023.0    387.0           2.0                 4.0               10.0
# 98   858092.0    420.0           4.0                 1.0               19.0
# 99   119314.0    420.0           5.0                 3.0               19.0
#
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#      order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329.0      1.0           1.0                 2.0                8.0
# 1   2398795.0      1.0           2.0                 3.0                7.0
# 2    473747.0      1.0           3.0                 3.0               12.0
# 3   2254736.0      1.0           4.0                 4.0                7.0
# 4    431534.0      1.0           5.0                 4.0               15.0
# 5   3367565.0      1.0           6.0                 2.0                7.0
# 6    550135.0      1.0           7.0                 1.0                9.0
# 7   3108588.0      1.0           8.0                 1.0               14.0
# 8   2295261.0      1.0           9.0                 1.0               16.0
# 9   2550362.0      1.0          10.0                 4.0                8.0
# 10  2968173.0     15.0          15.0                 1.0                9.0
# ...

# %%
# creating loyalty flag
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# confirming flag
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       1.0      New customer           1.0
# 1       1.0      New customer           2.0
# 2       1.0      New customer           3.0
# 3       1.0      New customer           4.0
# 4       1.0      New customer           5.0
# 5       1.0      New customer           6.0
# 6       1.0      New customer           7.0
# 7       1.0      New customer           8.0
# 8       1.0      New customer           9.0
# 9       1.0      New customer          10.0
# 10     15.0  Regular customer          15.0
# 11     15.0  Regular customer          17.0
# 12     15.0  Regular customer          18.0
# 13     15.0  Regular customer          21.0
# 14     15.0  Regular customer          22.0
# 15     19.0      New customer           2.0
# 16     19.0      New customer           5.0
# 17     19.0      New customer           7.0
# 18     21.0  Regular customer          10.0
# 19     31.0  Regular customer          10.0
# ...

# %% [markdown]
# ### Exercise

# %% [markdown]
# In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     15.457838
# 2.0     17.277920
# 3.0     17.170395
# 4.0     17.811403
# 5.0     15.215751
# 6.0     16.439806
# 7.0     17.225802
# 8.0     15.340650
# 9.0     15.895474
# 10.0    20.197148
# 11.0    16.170638
# 12.0    15.887671
# 13.0    16.583536
# 14.0    16.773669
# 15.0    16.165037
# 16.0    17.665606
# 17.0    15.694469
# 18.0    19.310397
# 19.0    17.177343
# 20.0    16.473447
# 21.0    22.902379
# Name: order_number, dtype: float64

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4.0     18.825780
# 7.0     17.472355
# 13.0    17.993423
# 14.0    19.246334
# 16.0    19.463012
# 17.0    11.294069
# 19.0    19.305237
# 20.0    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# The list shows now means for all department_ids, whereas the subset was only representing a few departments. Additionally. the means differ from the subset by +/-1 in value, which can also have significant impact on decision-making. So if possible, it would be always good to execute the code on the entire data frame.

# %% [markdown]
# The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# The average price of products purchased by loyal customers have a lower price than products purchased by new and regular customers.

# %% [markdown]
# ## Spending flag

# %% [markdown]
# The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# creating spending flag
ords_prods_merge.loc[ords_prods_merge['prices'] < 10, 'spending_flag'] = 'Low spender'
ords_prods_merge.loc[(ords_prods_merge['prices'] >= 10), 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.head(150)
# Out:
#       order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329.0      1.0           1.0                 2.0                8.0
# 1    2398795.0      1.0           2.0                 3.0                7.0
# 2     473747.0      1.0           3.0                 3.0               12.0
# 3    2254736.0      1.0           4.0                 4.0                7.0
# 4     431534.0      1.0           5.0                 4.0               15.0
# 5    3367565.0      1.0           6.0                 2.0                7.0
# 6     550135.0      1.0           7.0                 1.0                9.0
# 7    3108588.0      1.0           8.0                 1.0               14.0
# 8    2295261.0      1.0           9.0                 1.0               16.0
# 9    2550362.0      1.0          10.0                 4.0                8.0
# 10   2968173.0     15.0          15.0                 1.0                9.0
# ...

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     21760944
# High spender    10643926
# NaN                30200
# Name: spending_flag, dtype: int64

# %%
ords_prods_merge.groupby('spending_flag').agg({'avg_price': ['mean', 'min', 'max']})
# Out:
#                avg_price
#                     mean       min        max
# spending_flag
# High spender   12.471115  1.881818  25005.425
# Low spender    11.740117  1.000000  25005.425

# %% [markdown]
# Shouldn't the mean price for low spender category be below 10 according to the group's definition?

# %% [markdown]
# ## Frequent vs nonfrequent buyers

# %% [markdown]
# In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
ords_prods_merge['order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head(150)
# Out:
#       order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329.0      1.0           1.0                 2.0                8.0
# 1    2398795.0      1.0           2.0                 3.0                7.0
# 2     473747.0      1.0           3.0                 3.0               12.0
# 3    2254736.0      1.0           4.0                 4.0                7.0
# 4     431534.0      1.0           5.0                 4.0               15.0
# 5    3367565.0      1.0           6.0                 2.0                7.0
# 6     550135.0      1.0           7.0                 1.0                9.0
# 7    3108588.0      1.0           8.0                 1.0               14.0
# 8    2295261.0      1.0           9.0                 1.0               16.0
# 9    2550362.0      1.0          10.0                 4.0                8.0
# 10   2968173.0     15.0          15.0                 1.0                9.0
# ...

# %%
# creating frequency flag
ords_prods_merge.loc[ords_prods_merge['order_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['order_frequency'] <= 20) & (ords_prods_merge['order_frequency'] > 10), 'frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['order_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        21578273
# Regular customer          7217066
# Non-frequent customer     3639720
# NaN                            11
# Name: frequency_flag, dtype: int64

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data','orders_products_merged_v3.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32435070, 24)
