# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
#defining folder path
path = r'/Users/daniel/Library/CloudStorage/OneDrive-Persönlich/00 Synology/01 Dokumente/2023 Docs/99 CareerFoundry/04 Python/00 Instacart'

# %%
# importing pickle
ords_prod_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
#limiting to 1m rows
df = ords_prod_merged[:1000000]

# %%
#creating function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                1.0        0.0
# 1                    15.0         196                1.0        1.0
# 2                    21.0         196                1.0        1.0
# 3                    29.0         196                1.0        1.0
# 4                    28.0         196                1.0        1.0
#
#   product_name  aisle_id  department_id  prices _merge
# ...

# %%
# apply function on data frame
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/nc/z9t985y12f1dkrrfm_wn60n40000gn/T/ipykernel_1297/2882455508.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
#checking for max price in df
df['prices'].max()
# Out:
# 14.8

# %%
#defining conditions with loc
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/nc/z9t985y12f1dkrrfm_wn60n40000gn/T/ipykernel_1297/209343266.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#counting values
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
# applying loc to entire data frame ords_prods
ords_prod_merged.loc[ords_prod_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prod_merged.loc[(ords_prod_merged['prices'] <=15) & (ords_prod_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prod_merged.loc[ords_prod_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#counting values
ords_prod_merged['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid-range product     21860868
# Low-range product     10126324
# High-range product      417678
# NaN                      30200
# Name: price_range_loc, dtype: int64

# %%
#checking for max price in ords_prod
ords_prod_merged['prices'].max()
# Out:
# 99999.0

# %%
# counts of busiest days
ords_prod_merged['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0.0    6209808
# 1.0    5665951
# 6.0    4500391
# 2.0    4217868
# 5.0    4209603
# 3.0    3844175
# 4.0    3787263
# NaN         11
# Name: orders_day_of_week, dtype: int64

# %%
# defining busiest vs slow days
result = []

for value in ords_prod_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# assign result to data frame
ords_prod_merged['busiest_day'] = result

# %%
ords_prod_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437999
# Busiest day        6209808
# Least busy         3787263
# Name: busiest_day, dtype: int64

# %% [markdown]
# ## Exercise

# %% [markdown]
# Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# defining busiest vs slow days
results = []

for value in ords_prod_merged["orders_day_of_week"]:
  if value <= 1:
    results.append("Busiest days")
  elif value == 4 or value == 3:
    results.append("Least busy days")
  else:
    results.append("Regularly busy")

# %%
ords_prod_merged['Busiest_days'] = results

# %%
ords_prod_merged['Busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy     12927873
# Busiest days       11875759
# Least busy days     7631438
# Name: Busiest_days, dtype: int64

# %%
ords_prod_merged['orders_day_of_week'].head()
# Out:
# 0    2.0
# 1    3.0
# 2    3.0
# 3    4.0
# 4    4.0
# Name: orders_day_of_week, dtype: float64

# %%
# counts of busiest days
ords_prod_merged['orders_day_of_week'].value_counts(dropna=False)
# Out:
# 0.0    6209808
# 1.0    5665951
# 6.0    4500391
# 2.0    4217868
# 5.0    4209603
# 3.0    3844175
# 4.0    3787263
# NaN         11
# Name: orders_day_of_week, dtype: int64

# %%
# sum of busiest days (Saturday 0 and Sunday 1)
6209808 + 5665951
# Out:
# 11875759

# %% [markdown]
# The sum of the value counts for Saturday and Sunday matches the new categorization of "busiest days".

# %% [markdown]
# When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.

# %%
#busiest hours of day
ords_prod_merged['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10.0    2764476
# 11.0    2738647
# 14.0    2691598
# 15.0    2664583
# 13.0    2663346
# 12.0    2620898
# 16.0    2537506
# 9.0     2456751
# 17.0    2089510
# 8.0     1719991
# 18.0    1637956
# 19.0    1259416
# 20.0     977049
# 7.0      891951
# 21.0     796379
# 22.0     634743
# 23.0     402621
# 6.0      290796
# 0.0      218951
# 1.0      115787
# 5.0       88064
# 2.0       69435
# 4.0       53284
# 3.0       51321
# NaN          11
# Name: order_hour_of_day, dtype: int64

# %%
# defining busiest vs slow hours
hours = []

for value in ords_prod_merged["order_hour_of_day"]:
  if value >= 10 and value <17:
    hours.append("Most orders")
  elif value >= 7 and value < 10 or value >=17 and value <24:
    hours.append("Average orders")
  else:
    hours.append("Fewest orders")

# %%
hours
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
ords_prod_merged['busiest_hours'] = hours

# %%
ords_prod_merged['busiest_hours'].value_counts(dropna=False)
# Out:
# Most orders       18681054
# Average orders    12866367
# Fewest orders       887649
# Name: busiest_hours, dtype: int64

# %%
ords_prod_merged['order_hour_of_day'].count()
# Out:
# 32435059

# %%
ords_prod_merged['busiest_hours'].count()
# Out:
# 32435070

# %% [markdown]
# Count of both columns is almost identical.

# %%
# Exporting data frame as pickle
ords_prod_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_v2.pkl'))
